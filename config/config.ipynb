# %%
import os 
import yaml
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# False

# %%
class AppConfig:
    def __init__(self):
        self.config = self.load_config()
    
    def load_config(self):
        with open('config.yaml', 'r') as f:
            config = yaml.safe_load(f)
        
        if 'api' in config and 'key' in config['api']:
            config['api']['key'] = os.getenv('API_KEY')
        
        return config

# %%
app_config = AppConfig()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 app_config = AppConfig()
#
# Cell In[7], line 3, in AppConfig.__init__(self)
#       2 def __init__(self):
# ----> 3     self.config = self.load_config()
#
# Cell In[7], line 9, in AppConfig.load_config(self)
#       6 with open('config.yaml', 'r') as f:
#       7     config = yaml.safe_load(f)
# ----> 9 if 'api' in config and 'key' in config['api']:
#      10     config['api']['key'] = os.getenv('API_KEY')
#      12 return config
#
# TypeError: argument of type 'NoneType' is not iterable
